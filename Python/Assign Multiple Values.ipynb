# %%
#Python allows you to assign values to multiple variables in one line:
x,y,z='Bus', 'Train',"Cycle"
print(x,y,z)
# Out:
# Bus Train Cycle

# %%
a,b,c=[100, 200, 300]
print(a,b,c)
# Out:
# 100 200 300

# %%
a,b,c= 100, 'Bus', 300.00
print(a,"|",b,"|",c)
# Out:
# 100 | Bus | 300.0

# %%
a=b=c="Same value"
print(a, b, c)
# Out:
# Same value Same value Same value

# %%
#Unpack a list to various person
vehicle=['Bus', 'Truck', 'Train']
a,b,c=vehicle
print(a,b,c)
a=b=c=vehicle # all values will be assigned to each veriable
print(a,b,c)
# Out:
# Bus Truck Train
# ['Bus', 'Truck', 'Train'] ['Bus', 'Truck', 'Train'] ['Bus', 'Truck', 'Train']

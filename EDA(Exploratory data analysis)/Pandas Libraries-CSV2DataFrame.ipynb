# %%
# Pandas: a popular libraries or dependencies for data analysis.

'''
At the very first, we import python and now we've large number of library functions those we can easily access:
1. read_csv()
2. Series()
3. DataFrame
4. values
'''
import pandas as pd #shortening the pandas as pd

path = '/content/drive/MyDrive/Colab Notebooks/Colabfiles/ACD to do list - 2do.csv' # the csv file path has been copied to path

# Now CSV file to DataFrame Creation:
# using pandas library as read_csv using the file path and df is DataFrame(dataset with row and column) where the result is stored.

df = pd.read_csv(path)

# Now we can easily call head() with the DataFrame and it will show 5 rows automatically:
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#   Assigned Date          Website  \
# 0           NaN  Legitimacy Life
# 1           NaN              ACD
# 2           NaN              ACD
# 3           NaN     Muslim Ummah
# 4           NaN     Muslim Ummah
#
#                                          Task Name          Task Details  \
# 0                        Polling email discussion   need to post as news
# 1            ACD all input methods from Rasel bhai                     ✅
# 2                    ACD, Life, b2Root credentials                     ✅
# 3                Post khutba translation of 09 Feb                     ✅
# 4  Check Whatsapp message about khutba of Rajshahi                     ❌
#
# ...

# %%
# @title Assigned Date

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Assigned Date').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
